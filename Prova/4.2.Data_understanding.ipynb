# %% [markdown]
# # Data Understanding
#
# Perform the necessary steps to better understand the data.
#
# We omit the step of data collection because I give you all the necessary data.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load dataset

# %%
df = pd.read_csv('house_pricing.csv', sep=',')

# %% [markdown]
# ## Describe the data
#
# Perform a first, basic, inspection of the data: dimensions, first rows, column types, etc.

# %%
print(df.head(3))
# Out:
#      Split  Id MSZoning  LotArea Street Utilities LandSlope HouseStyle  \
# 0  labeled   1       RL     6173   Pave    AllPub       Gtl     1Story
# 1  labeled   2       RL    11200   Pave    AllPub       Gtl     1Story
# 2  labeled   3       RL    11924   Pave    AllPub       Gtl     2Story
#
#    YearBuilt  YearRemodAdd  ... GarageFinish GarageCars  GarageArea  \
# 0     1967.0          1967  ...          Unf          1         288
# 1     1985.0          1985  ...          Unf          2         403
# 2     2005.0          2006  ...          Fin          3         736
#
#   PavedDrive OpenPorchSF EnclosedPorch  PoolArea  MiscFeature  SalePrice  \
# 0          Y           0             0         0          NaN   125500.0
# 1          Y          26             0         0          NaN   180000.0
# 2          Y          21             0         0          NaN   345000.0
#
#    Electtrical
# 0          NaN
# 1          NaN
# 2          NaN
#
# [3 rows x 37 columns]

# %%
print("\n ______________________SHAPE________________ \n")
print(df.shape)
print("\n ____________________DESCRIBE_______________ \n")
print(df.describe().T)
# Out:
#  ______________________SHAPE________________
#
# (992, 37)
#
#  ____________________DESCRIBE_______________
#
#                count           mean           std      min        25%  \
# Id             992.0     496.500000    286.510035      1.0     248.75
# LotArea        992.0    9410.156250   7785.723978   1300.0    7195.00
# YearBuilt      992.0    1971.371976     28.455495   1875.0    1955.00
# YearRemodAdd   992.0    1983.533266     20.467614   1950.0    1965.00
# TotalBsmtSF    992.0     984.961694    359.197354      0.0     780.00
# 1stFlrSF       992.0    1075.716734    314.548034    438.0     848.00
# 2ndFlrSF       992.0     307.084677    397.709845      0.0       0.00
# GrLivArea      992.0    1386.252016    418.581680    438.0    1066.50
# BsmtFullBath   992.0       0.393145      0.498912      0.0       0.00
# FullBath       992.0       1.496976      0.525813      0.0       1.00
# BedroomAbvGr   992.0       2.813508      0.735779      0.0       2.00
# ...

# %%
print( "\n ______________________INFO________________\n")
print(df.info())
# Out:
#  ______________________INFO________________
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Split          992 non-null    object
#  1   Id             992 non-null    int64
#  2   MSZoning       992 non-null    object
#  3   LotArea        992 non-null    int64
#  4   Street         992 non-null    object
#  5   Utilities      992 non-null    object
#  6   LandSlope      992 non-null    object
#  7   HouseStyle     992 non-null    object
#  8   YearBuilt      992 non-null    float64
#  9   YearRemodAdd   992 non-null    int64
#  10  RoofStyle      992 non-null    object
#  11  Foundation     992 non-null    object
#  12  TotalBsmtSF    992 non-null    int64
#  13  Heating        992 non-null    object
#  14  CentralAir     992 non-null    object
#  15  Electrical     961 non-null    object
# ...

# %%
print(' \n Check column types.→Pandas: dtypes, info \n')
print( "\n ______________________DATA TYPE________________\n")
print (df.dtypes)
# Out:
#
#  Check column types.→Pandas: dtypes, info
#
#
#  ______________________DATA TYPE________________
#
# Split             object
# Id                 int64
# MSZoning          object
# LotArea            int64
# Street            object
# Utilities         object
# LandSlope         object
# HouseStyle        object
# YearBuilt        float64
# YearRemodAdd       int64
# RoofStyle         object
# Foundation        object
# TotalBsmtSF        int64
# Heating           object
# CentralAir        object
# Electrical        object
# 1stFlrSF           int64
# 2ndFlrSF           int64
# GrLivArea          int64
# BsmtFullBath       int64
# FullBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageType        object
# GarageYrBlt      float64
# GarageFinish      object
# GarageCars         int64
# GarageArea         int64
# PavedDrive        object
# OpenPorchSF        int64
# EnclosedPorch      int64
# ...

# %%
df.describe().T
# Out:
#                count           mean           std      min        25%  \
# Id             992.0     496.500000    286.510035      1.0     248.75
# LotArea        992.0    9410.156250   7785.723978   1300.0    7195.00
# YearBuilt      992.0    1971.371976     28.455495   1875.0    1955.00
# YearRemodAdd   992.0    1983.533266     20.467614   1950.0    1965.00
# TotalBsmtSF    992.0     984.961694    359.197354      0.0     780.00
# 1stFlrSF       992.0    1075.716734    314.548034    438.0     848.00
# 2ndFlrSF       992.0     307.084677    397.709845      0.0       0.00
# GrLivArea      992.0    1386.252016    418.581680    438.0    1066.50
# BsmtFullBath   992.0       0.393145      0.498912      0.0       0.00
# FullBath       992.0       1.496976      0.525813      0.0       1.00
# BedroomAbvGr   992.0       2.813508      0.735779      0.0       2.00
# KitchenAbvGr   992.0       1.036290      0.197598      0.0       1.00
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Split          992 non-null    object
#  1   Id             992 non-null    int64
#  2   MSZoning       992 non-null    object
#  3   LotArea        992 non-null    int64
#  4   Street         992 non-null    object
#  5   Utilities      992 non-null    object
#  6   LandSlope      992 non-null    object
#  7   HouseStyle     992 non-null    object
#  8   YearBuilt      992 non-null    float64
#  9   YearRemodAdd   992 non-null    int64
#  10  RoofStyle      992 non-null    object
#  11  Foundation     992 non-null    object
#  12  TotalBsmtSF    992 non-null    int64
#  13  Heating        992 non-null    object
#  14  CentralAir     992 non-null    object
#  15  Electrical     961 non-null    object
#  16  1stFlrSF       992 non-null    int64
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Split          992 non-null    object
#  1   Id             992 non-null    int64
#  2   MSZoning       992 non-null    object
#  3   LotArea        992 non-null    int64
#  4   Street         992 non-null    object
#  5   Utilities      992 non-null    object
#  6   LandSlope      992 non-null    object
#  7   HouseStyle     992 non-null    object
#  8   YearBuilt      992 non-null    float64
#  9   YearRemodAdd   992 non-null    int64
#  10  RoofStyle      992 non-null    object
#  11  Foundation     992 non-null    object
#  12  TotalBsmtSF    992 non-null    int64
#  13  Heating        992 non-null    object
#  14  CentralAir     992 non-null    object
#  15  Electrical     961 non-null    object
#  16  1stFlrSF       992 non-null    int64
# ...

# %%
# Valori nulli assoluti e percentuali
null_info = pd.DataFrame({
    'Nulli': df.isnull().sum(),
    'Percentuale': (df.isnull().sum() / len(df)) * 100
})
print(null_info)
# Out:
#                Nulli  Percentuale
# Split              0     0.000000
# Id                 0     0.000000
# MSZoning           0     0.000000
# LotArea            0     0.000000
# Street             0     0.000000
# Utilities          0     0.000000
# LandSlope          0     0.000000
# HouseStyle         0     0.000000
# YearBuilt          0     0.000000
# YearRemodAdd       0     0.000000
# RoofStyle          0     0.000000
# Foundation         0     0.000000
# TotalBsmtSF        0     0.000000
# Heating            0     0.000000
# CentralAir         0     0.000000
# Electrical        31     3.125000
# 1stFlrSF           0     0.000000
# 2ndFlrSF           0     0.000000
# GrLivArea          0     0.000000
# BsmtFullBath       0     0.000000
# FullBath           0     0.000000
# BedroomAbvGr       0     0.000000
# KitchenAbvGr       0     0.000000
# TotRmsAbvGrd       0     0.000000
# Fireplaces         0     0.000000
# GarageType        54     5.443548
# ...

# %%
#Overview numeriche:
numeriche = [
   'LotArea', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF',
    '1stFlrSF', '2ndFlrSF', 'GrLivArea', 'BsmtFullBath',
    'FullBath', 'BedroomAbvGr', 'KitchenAbvGr',
    'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt',
    'GarageCars', 'GarageArea', 'OpenPorchSF',
    'EnclosedPorch', 'PoolArea'
]
 
df[numeriche].describe()
# Out:
#              LotArea    YearBuilt  YearRemodAdd  TotalBsmtSF     1stFlrSF  \
# count     992.000000   992.000000    992.000000   992.000000   992.000000
# mean     9410.156250  1971.371976   1983.533266   984.961694  1075.716734
# std      7785.723978    28.455495     20.467614   359.197354   314.548034
# min      1300.000000  1875.000000   1950.000000     0.000000   438.000000
# 25%      7195.000000  1955.000000   1965.000000   780.000000   848.000000
# 50%      9019.000000  1971.000000   1991.000000   941.000000  1026.000000
# 75%     10833.750000  1999.000000   2003.000000  1187.250000  1252.000000
# max    164660.000000  2009.000000   2010.000000  3206.000000  2259.000000
#
#           2ndFlrSF    GrLivArea  BsmtFullBath    FullBath  BedroomAbvGr  \
# count   992.000000   992.000000    992.000000  992.000000    992.000000
# mean    307.084677  1386.252016      0.393145    1.496976      2.813508
# std     397.709845   418.581680      0.498912    0.525813      0.735779
# ...

# %%
categoriche = ['MSZoning', 'Street', 'Utilities', 'LandSlope', 'HouseStyle', 
               'RoofStyle', 'Foundation', 'Heating', 'CentralAir','Electrical', 
               'GarageType', 'GarageFinish', 'PavedDrive', 'MiscFeature']

for col in categoriche:
    print(f"\n{col}:")
    print(df[col].value_counts())
# Out:
# MSZoning:
# MSZoning
# RL         761
# RM         165
# FV          52
# RH          12
# C (all)      2
# Name: count, dtype: int64
#
# Street:
# Street
# Pave    988
# Grvl      4
# Name: count, dtype: int64
#
# Utilities:
# Utilities
# AllPub    991
# NoSeWa      1
# Name: count, dtype: int64
#
# LandSlope:
# LandSlope
# Gtl    955
# Mod     34
# Sev      3
# Name: count, dtype: int64
#
# HouseStyle:
# HouseStyle
# 1Story    503
# 2Story    290
# 1.5Fin     99
# SLvl       48
# SFoyer     33
# 1.5Unf     12
# 2.5Unf      5
# 2.5Fin      2
# Name: count, dtype: int64
#
# RoofStyle:
# RoofStyle
# Gable      821
# Hip        158
# Mansard      7
# Gambrel      3
# Flat         3
# Name: count, dtype: int64
#
# Foundation:
# Foundation
# CBlock    468
# PConc     417
# BrkTil     87
# Slab       16
# Stone       4
# Name: count, dtype: int64
#
# Heating:
# Heating
# GasA     973
# GasW      10
# Grav       5
# Wall       3
# Floor      1
# Name: count, dtype: int64
#
# CentralAir:
# ...

# %% [markdown]
# trovare numeri negativi

# %%
   # Trova colonne con negativi
# Trova colonne con negativi
for col in df.select_dtypes(include=['int64', 'float64']).columns:
    negativi = (df[col] < 0).sum()
    if negativi > 0:
        print(f"{col}: {negativi} negativi (min: {df[col].min()})")
    else:
        print("no negativi")
# Out:
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi
# no negativi

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# Summarize main characteristics of the data with visualizations.
#
# Exploratory Data Analysis (EDA)
# • Column distributions.→Pandas: hist, boxplot, bar; Matplotlib.pyplot: hist, boxplot, barplot
# • Correlations between features.→ Pandas: corr; Seaborn: heatmap
# • Relations between features (e.g., pair-plot).→Pandas.plotting: scatter_matrix; Seaborn: pairplot
# • Correlations with the target feature.→Pandas: corr
# • Any interesting insights about the data.

# %% [markdown]
# ### Feature distributions
#
# Check the distributions of numerical features (histogram or boxplot) and categorical features (bar plot).

# %%
df.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Feature correlation
#
# Display the correlation between pairs of features. This is normally done with the correlation matrix.
#
# Also, display in the same plot or a different one the correlation of features with the target feature.

# %% [markdown]
# ### Pairplot
#
# Visualize the relationship of different features with a pairplot.

# %% [markdown]
# ### Anything else?
#
# With all the information you've gathered so far, are there any other plots or data you'd like to check before proceeding with the cleaning and processing?

# %% [markdown]
# ## Verify Data Quality
#
# - Is the data correct? Does any column contain important errors that should be corrected?
# - What about missing values?
#     - How are they represented (e.g., empty string, NaN, -1, etc.)?
#     - Where do they occur?
#     - How common are they?
# - Do not change the data, just inspect where these problems occur.
